# %%
# Before you start, make sure you have installed the required pgvector extension
# on MacOS you can use brew to install the postgres app which included the extension
# $ brew install --cask postgres-unofficial
# create a new database with the name `vondel`

# Install required libraries
# %pip install psycopg2-binary openai numpy
# Out:
# Requirement already satisfied: psycopg2-binary in ./.venv/lib/python3.12/site-packages (2.9.9)
# Requirement already satisfied: openai in ./.venv/lib/python3.12/site-packages (1.35.10)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.12/site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.12/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./.venv/lib/python3.12/site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.12/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in ./.venv/lib/python3.12/site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in ./.venv/lib/python3.12/site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
#
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2
import numpy as np
import os
from openai import OpenAI

from dotenv import load_dotenv

load_dotenv()

OpenAI.api_key = os.getenv("OPENAI_API_KEY")

client = OpenAI()

# %%
def connect_to_db():
    conn = psycopg2.connect(
        dbname=os.getenv("DB_NAME"),
        user=os.getenv("DB_USER"),
        password=os.getenv("DB_PASSWORD"),
        host=os.getenv("DB_HOST"),
        port=os.getenv("DB_PORT")
    )
    return conn

def initialize_db(conn):
    cur = conn.cursor()
    cur.execute("CREATE EXTENSION IF NOT EXISTS vector;")
    cur.execute("""
    CREATE TABLE IF NOT EXISTS pages (
        id SERIAL PRIMARY KEY,
        content TEXT,
        embedding VECTOR
    );
    """)
    conn.commit()
    cur.close()

def insert_document(conn, content, embedding):
    cur = conn.cursor()
    cur.execute(
        "INSERT INTO pages (content, embedding) VALUES (%s, %s)",
        (content, embedding.tolist())
    )
    conn.commit()
    cur.close()
    
def generate_embedding(text):
    response = client.embeddings.create(input=text, model="text-embedding-3-small")
    return np.array(response.data[0].embedding)


conn = connect_to_db()
initialize_db(conn)

# Get all OCR files from the ocr-step-2 directory
improved_files = [f'./ocr-step-2/{file}' for file in os.listdir('./ocr-step-2') if file.endswith('.txt')]

# Generate embeddings for all files, inset in database
for file in improved_files:
    with open(file, 'r') as f:
        content = f.read()
        embedding = generate_embedding(content)
        insert_document(conn, content, embedding)
        print(f"Inserted {file} into the database")

conn.close()
# Out:
# Inserted ./ocr-step-2/page_127.txt into the database
# Inserted ./ocr-step-2/page_133.txt into the database
# Inserted ./ocr-step-2/page_24.txt into the database
# Inserted ./ocr-step-2/page_30.txt into the database
# Inserted ./ocr-step-2/page_31.txt into the database
# Inserted ./ocr-step-2/page_25.txt into the database
# Inserted ./ocr-step-2/page_132.txt into the database
# Inserted ./ocr-step-2/page_126.txt into the database
# Inserted ./ocr-step-2/page_130.txt into the database
# Inserted ./ocr-step-2/page_124.txt into the database
# Inserted ./ocr-step-2/page_118.txt into the database
# Inserted ./ocr-step-2/page_33.txt into the database
# Inserted ./ocr-step-2/page_27.txt into the database
# Inserted ./ocr-step-2/page_26.txt into the database
# Inserted ./ocr-step-2/page_32.txt into the database
# Inserted ./ocr-step-2/page_119.txt into the database
# Inserted ./ocr-step-2/page_125.txt into the database
# Inserted ./ocr-step-2/page_131.txt into the database
# Inserted ./ocr-step-2/page_109.txt into the database
# Inserted ./ocr-step-2/page_135.txt into the database
# Inserted ./ocr-step-2/page_121.txt into the database
# Inserted ./ocr-step-2/page_36.txt into the database
# Inserted ./ocr-step-2/page_23.txt into the database
# Inserted ./ocr-step-2/page_37.txt into the database
# Inserted ./ocr-step-2/page_120.txt into the database
# Inserted ./ocr-step-2/page_134.txt into the database
# Inserted ./ocr-step-2/page_108.txt into the database
# Inserted ./ocr-step-2/page_122.txt into the database
# Inserted ./ocr-step-2/page_136.txt into the database
# Inserted ./ocr-step-2/page_35.txt into the database
# Inserted ./ocr-step-2/page_34.txt into the database
# Inserted ./ocr-step-2/page_137.txt into the database
# Inserted ./ocr-step-2/page_123.txt into the database
# Inserted ./ocr-step-2/page_144.txt into the database
# Inserted ./ocr-step-2/page_150.txt into the database
# Inserted ./ocr-step-2/page_84.txt into the database
# Inserted ./ocr-step-2/page_90.txt into the database
# Inserted ./ocr-step-2/page_47.txt into the database
# Inserted ./ocr-step-2/page_53.txt into the database
# Inserted ./ocr-step-2/page_52.txt into the database
# Inserted ./ocr-step-2/page_46.txt into the database
# Inserted ./ocr-step-2/page_91.txt into the database
# Inserted ./ocr-step-2/page_85.txt into the database
# Inserted ./ocr-step-2/page_151.txt into the database
# Inserted ./ocr-step-2/page_145.txt into the database
# Inserted ./ocr-step-2/page_153.txt into the database
# Inserted ./ocr-step-2/page_147.txt into the database
# Inserted ./ocr-step-2/page_93.txt into the database
# Inserted ./ocr-step-2/page_87.txt into the database
# Inserted ./ocr-step-2/page_50.txt into the database
# Inserted ./ocr-step-2/page_44.txt into the database
# Inserted ./ocr-step-2/page_78.txt into the database
# Inserted ./ocr-step-2/page_79.txt into the database
# Inserted ./ocr-step-2/page_45.txt into the database
# Inserted ./ocr-step-2/page_51.txt into the database
# Inserted ./ocr-step-2/page_86.txt into the database
# Inserted ./ocr-step-2/page_92.txt into the database
# Inserted ./ocr-step-2/page_146.txt into the database
# Inserted ./ocr-step-2/page_152.txt into the database
# Inserted ./ocr-step-2/page_156.txt into the database
# Inserted ./ocr-step-2/page_142.txt into the database
# Inserted ./ocr-step-2/page_96.txt into the database
# Inserted ./ocr-step-2/page_82.txt into the database
# Inserted ./ocr-step-2/page_69.txt into the database
# Inserted ./ocr-step-2/page_55.txt into the database
# Inserted ./ocr-step-2/page_41.txt into the database
# Inserted ./ocr-step-2/page_40.txt into the database
# Inserted ./ocr-step-2/page_54.txt into the database
# Inserted ./ocr-step-2/page_68.txt into the database
# Inserted ./ocr-step-2/page_83.txt into the database
# Inserted ./ocr-step-2/page_97.txt into the database
# Inserted ./ocr-step-2/page_143.txt into the database
# Inserted ./ocr-step-2/page_157.txt into the database
# Inserted ./ocr-step-2/page_141.txt into the database
# Inserted ./ocr-step-2/page_155.txt into the database
# Inserted ./ocr-step-2/page_81.txt into the database
# Inserted ./ocr-step-2/page_95.txt into the database
# Inserted ./ocr-step-2/page_42.txt into the database
# Inserted ./ocr-step-2/page_56.txt into the database
# Inserted ./ocr-step-2/page_57.txt into the database
# Inserted ./ocr-step-2/page_43.txt into the database
# Inserted ./ocr-step-2/page_94.txt into the database
# Inserted ./ocr-step-2/page_80.txt into the database
# Inserted ./ocr-step-2/page_154.txt into the database
# Inserted ./ocr-step-2/page_140.txt into the database
# Inserted ./ocr-step-2/page_159.txt into the database
# Inserted ./ocr-step-2/page_99.txt into the database
# Inserted ./ocr-step-2/page_66.txt into the database
# Inserted ./ocr-step-2/page_72.txt into the database
# Inserted ./ocr-step-2/page_73.txt into the database
# Inserted ./ocr-step-2/page_67.txt into the database
# Inserted ./ocr-step-2/page_98.txt into the database
# Inserted ./ocr-step-2/page_158.txt into the database
# Inserted ./ocr-step-2/page_71.txt into the database
# Inserted ./ocr-step-2/page_65.txt into the database
# Inserted ./ocr-step-2/page_59.txt into the database
# Inserted ./ocr-step-2/page_58.txt into the database
# Inserted ./ocr-step-2/page_64.txt into the database
# Inserted ./ocr-step-2/page_70.txt into the database
# Inserted ./ocr-step-2/page_163.txt into the database
# Inserted ./ocr-step-2/page_48.txt into the database
# Inserted ./ocr-step-2/page_74.txt into the database
# Inserted ./ocr-step-2/page_60.txt into the database
# Inserted ./ocr-step-2/page_61.txt into the database
# Inserted ./ocr-step-2/page_75.txt into the database
# Inserted ./ocr-step-2/page_49.txt into the database
# Inserted ./ocr-step-2/page_162.txt into the database
# Inserted ./ocr-step-2/page_148.txt into the database
# Inserted ./ocr-step-2/page_160.txt into the database
# Inserted ./ocr-step-2/page_88.txt into the database
# Inserted ./ocr-step-2/page_63.txt into the database
# Inserted ./ocr-step-2/page_77.txt into the database
# Inserted ./ocr-step-2/page_76.txt into the database
# Inserted ./ocr-step-2/page_62.txt into the database
# Inserted ./ocr-step-2/page_89.txt into the database
# Inserted ./ocr-step-2/page_161.txt into the database
# Inserted ./ocr-step-2/page_149.txt into the database
# Inserted ./ocr-step-2/page_106.txt into the database
# Inserted ./ocr-step-2/page_112.txt into the database
# Inserted ./ocr-step-2/page_39.txt into the database
# Inserted ./ocr-step-2/page_38.txt into the database
# Inserted ./ocr-step-2/page_113.txt into the database
# Inserted ./ocr-step-2/page_107.txt into the database
# Inserted ./ocr-step-2/page_111.txt into the database
# Inserted ./ocr-step-2/page_105.txt into the database
# Inserted ./ocr-step-2/page_139.txt into the database
# Inserted ./ocr-step-2/page_138.txt into the database
# Inserted ./ocr-step-2/page_104.txt into the database
# Inserted ./ocr-step-2/page_110.txt into the database
# Inserted ./ocr-step-2/page_128.txt into the database
# Inserted ./ocr-step-2/page_114.txt into the database
# Inserted ./ocr-step-2/page_100.txt into the database
# Inserted ./ocr-step-2/page_101.txt into the database
# Inserted ./ocr-step-2/page_115.txt into the database
# Inserted ./ocr-step-2/page_129.txt into the database
# Inserted ./ocr-step-2/page_103.txt into the database
# Inserted ./ocr-step-2/page_117.txt into the database
# Inserted ./ocr-step-2/page_28.txt into the database
# Inserted ./ocr-step-2/page_29.txt into the database
# Inserted ./ocr-step-2/page_116.txt into the database
# Inserted ./ocr-step-2/page_102.txt into the database
